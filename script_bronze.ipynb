# %%
import pandas as pd 
from sqlalchemy import create_engine
import psycopg2

# %%
#### Importando classes
from utils.extract import Extract
from utils.utils import printSchema
##################################

# %%
#### Definindo o valor das váriaveis 
key = '88378df40a7ab0fb352a3043054bc006'
page = 1
page_final = 2
dados = []

# %%
#### Declarando a classe
exec = Extract(key)

# %%
while page <= page_final:
    print(f'Procurando os identificadores de filmes da página {page}')

    movie_ids = exec.get_movies(page)
    for movie_id in movie_ids:
        print(f'Procurando os detalhes do filme ID {movie_id}')
        movie_details = exec.get_movie_details(movie_id)
        dados.append(movie_details)
    page +=1
# Out:
# Procurando os identificadores de filmes da página 1
# Procurando os detalhes do filme ID 533535
# Procurando os detalhes do filme ID 957452
# Procurando os detalhes do filme ID 365177
# Procurando os detalhes do filme ID 1022789
# Procurando os detalhes do filme ID 519182
# Procurando os detalhes do filme ID 917496
# Procurando os detalhes do filme ID 646097
# Procurando os detalhes do filme ID 573435
# Procurando os detalhes do filme ID 1139817
# Procurando os detalhes do filme ID 1064028
# Procurando os detalhes do filme ID 945961
# Procurando os detalhes do filme ID 698687
# Procurando os detalhes do filme ID 1005076
# Procurando os detalhes do filme ID 1079091
# Procurando os detalhes do filme ID 718821
# Procurando os detalhes do filme ID 970347
# Procurando os detalhes do filme ID 748783
# Procurando os detalhes do filme ID 831815
# Procurando os detalhes do filme ID 923667
# Procurando os detalhes do filme ID 4011
# Procurando os identificadores de filmes da página 2
# Procurando os detalhes do filme ID 748167
# Procurando os detalhes do filme ID 762441
# Procurando os detalhes do filme ID 1160018
# Procurando os detalhes do filme ID 666035
# Procurando os detalhes do filme ID 1226578
# Procurando os detalhes do filme ID 840705
# Procurando os detalhes do filme ID 1134424
# Procurando os detalhes do filme ID 653346
# Procurando os detalhes do filme ID 7451
# Procurando os detalhes do filme ID 786892
# Procurando os detalhes do filme ID 704239
# Procurando os detalhes do filme ID 592695
# Procurando os detalhes do filme ID 482600
# Procurando os detalhes do filme ID 5492
# Procurando os detalhes do filme ID 933260
# Procurando os detalhes do filme ID 1129598
# Procurando os detalhes do filme ID 1115396
# Procurando os detalhes do filme ID 1032823
# Procurando os detalhes do filme ID 826510
# Procurando os detalhes do filme ID 588648

# %%
df = pd.DataFrame(dados)

# %%
printSchema(df)

# %%
display(df)
# Out:
#                                             title  vote_average  year  \
# 0                            Deadpool & Wolverine         7.704  2024
# 1                                        The Crow         5.365  2024
# 2                                     Borderlands         5.863  2024
# 3                                    Inside Out 2         7.665  2024
# 4                                 Despicable Me 4         7.170  2024
# 5                         Beetlejuice Beetlejuice         7.101  2024
# 6                                     Rebel Ridge         7.040  2024
# 7                           Bad Boys: Ride or Die         7.554  2024
# 8                              Officer Black Belt         7.816  2024
# 9                                    Subservience         6.131  2024
# 10                                 Alien: Romulus         7.100  2024
# 11                               Transformers One         7.200  2024
# 12                                        Duchess         5.800  2024
# 13                                It Ends with Us         6.717  2024
# 14                                       Twisters         6.982  2024
# 15                                     The Killer         6.596  2024
# 16                             The Garfield Movie         7.113  2024
# 17   Saving Bikini Bottom: The Sandy Cheeks Movie         0.000  2024
# 18            Twilight of the Warriors: Walled In         6.687  2024
# 19                                    Beetlejuice         7.377  1988
# 20                                         Uglies         6.029  2024
# 21                         A Quiet Place: Day One         6.809  2024
# 22                                           Kill         7.000  2024
# 23                                     Wanted Man         7.087  2024
# 24                                       Longlegs         6.695  2024
# 25                                    Blink Twice         6.700  2024
# 26  Mantra Warrior: The Legend of The Eight Moons         5.900  2023
# 27              Kingdom of the Planet of the Apes         7.136  2024
# 28                                            xXx         5.939  2002
# 29                        Furiosa: A Mad Max Saga         7.567  2024
# 30                                      The Union         6.300  2024
# 31                                       Pleasure         6.200  2021
# 32                                   Japanese Mom         7.682  2017
# 33                                         Gunner         5.431  2024
# 34                                  The Substance         7.800  2024
# 35                                           Prey         6.426  2024
# 36                                  Hunting Games         4.500  2023
# 37                                           Trap         6.508  2024
# 38                   Harold and the Purple Crayon         7.000  2024
# 39                                   Dragonkeeper         7.282  2024
#
#        budget     revenue                                             genres
# 0   200000000  1306813178                    Action, Comedy, Science fiction
# 1    50000000    13690814                            Action, Fantasy, Horror
# 2   115000000    30863794  Action, Science fiction, Comedy, Adventure, Th...
# 3   200000000  1676778335      Animation, Family, Adventure, Comedy, Fantasy
# 4   100000000   940356614                  Animation, Family, Comedy, Action
# 5   100000000   267268543                            Comedy, Horror, Fantasy
# 6           0           0                            Crime, Action, Thriller
# 7   100000000   402529640                    Action, Crime, Thriller, Comedy
# 8           0           0                              Action, Comedy, Crime
# 9           0           0                  Science fiction, Thriller, Horror
# 10   80000000   330717297                    Horror, Science fiction, Action
# 11  111000000        4239      Animation, Science fiction, Adventure, Family
# 12          0           0                            Action, Crime, Thriller
# 13   25000000   325480247                                     Romance, Drama
# 14  155000000   364092150                        Action, Adventure, Thriller
# 15   30000000           0                            Action, Thriller, Crime
# 16   60000000   230295748       Animation, Comedy, Family, Adventure, Action
# 17  100000000           0               Animation, Comedy, Adventure, Family
# 18   38400000    95335412                 Action, Adventure, Crime, Thriller
# 19   15000000    84554197                                    Fantasy, Comedy
# 20          0           0                 Science fiction, Adventure, Action
# 21   67000000   260894737                  Horror, Science fiction, Thriller
# 22    3000000     5400000                                      Action, Crime
# 23          0           0                                             Action
# 24   10000000   102469694                            Crime, Horror, Thriller
# 25   20000000    43136879                                  Mystery, Thriller
# 26          0           0  Animation, Action, Adventure, Fantasy, Science...
# 27  160000000   397366385                 Science fiction, Adventure, Action
# 28   70000000   277448382                 Action, Adventure, Thriller, Crime
# 29  170000000   172775791                 Action, Adventure, Science fiction
# 30          0           0                                     Action, Comedy
# 31    1800000      393824                                              Drama
# 32          0           0                                     Romance, Drama
# 33   20000000           0                            Action, Thriller, Crime
# 34          0           0                     Drama, Horror, Science fiction
# 35          0           0                                   Action, Thriller
# 36          0           0                         Action, Thriller, Tv movie
# 37   30000000    77046616                            Thriller, Crime, Horror
# 38   40000000    24982787                 Adventure, Family, Fantasy, Comedy
# 39   25600000     5427272      Action, Adventure, Animation, Family, Fantasy

# %%
engine = create_engine('postgresql://teste_xd8n_user:F8IpuKfkJNWF27EPvjQPPoxBRZIz5mAX@dpg-crnjkee8ii6s73esmf20-a.oregon-postgres.render.com/teste_xd8n')

# %%
df.to_sql('bruto_filmes', con=engine, schema='bronze', if_exists='append', index=False)
# Out:
# 40
